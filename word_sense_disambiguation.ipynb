# %%
x = " A mouse typically controls the motion of a pointer in two dimensions in a graphical user interface (GUI). The mouse turns movements of the hand backward and forward, left and right into equivalent electronic signals that in turn are used to move the pointer. The first public demonstration of the mouse was in 1968 by Douglas Engelbart at the Fall Joint Computer Conference in San Francisco. The demonstration included the mouse, video conferencing, teleconferencing, hypertext, word processing, hypermedia, object addressing and dynamic file linking. The mouse became a popular pointing device after Apple Inc. released it with the Lisa personal computer in 1983. Microsoft Windows 1.0 was released in 1985 and also required a mouse to operate. By the early 1990s, the mouse had become a standard component of personal computers."

# %%
import nltk
nltk.download('punkt')
nltk.download('wordnet')

from nltk.tokenize import word_tokenize
from nltk.wsd import lesk
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Smriti\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Smriti\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
l = lesk(word_tokenize(x), "mouse")

# %%
l.definition()
# Out:
# 'a hand-operated electronic device that controls the coordinates of a cursor on your computer screen as you move it around on a pad; on the bottom of the device is a ball that rolls on the surface of the pad'
